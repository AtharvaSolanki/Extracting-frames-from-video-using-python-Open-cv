# %%
import cv2 
  

vidObj = cv2.VideoCapture('C:\\Users\\user\\Desktop\\AI assignment\\assignment 2\\real\\male\\realm3.mp4') 
total=vidObj.get(7)
total
# Out:
# 298.0

# %%
import cv2 
  

def FrameCapture(path): 
      
    # Path to video file 
    vidObj = cv2.VideoCapture("C:\\Users\\user\\Desktop\\AI assignment\\assignment 4\\real\\r6.mp4") 
  
    # Used as counter variable 
    count = 0
  
    # checks whether frames were extracted 
    success = 1
  
    while success: 
  
        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read() 
  
        # Saves the frames with frame-count 
        cv2.imwrite("frame%d.jpg" % count, image) 
  
        count += 1

# %%
# Driver Code 
if __name__ == '__main__': 
  
    # Calling the function 
    FrameCapture('C:\\Users\\user\\Desktop\\AI assignment\\assignment\\spoof\\frames')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3636\1324977231.py in <module>
#       3
#       4     # Calling the function
# ----> 5     FrameCapture('C:\\Users\\user\\Desktop\\AI assignment\\assignment\\spoof\\frames')
#
# ~\AppData\Local\Temp\ipykernel_3636\4209814775.py in FrameCapture(path)
#      20
#      21         # Saves the frames with frame-count
# ---> 22         cv2.imwrite("frame%d.jpg" % count, image)
#      23
#      24         count += 1
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:783: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
import cv2
